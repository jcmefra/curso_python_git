# %%
import numpy as np
import pygimli as pg 
import pygimli.meshtools as mt
import pygimli.physics.traveltime as tt
import matplotlib.pyplot as plt

# %%
data = tt.load('refraccion_curso/refraccion_2/picks/picks_2.sgt')

# %%
print(data)
# Out:
# Data: Sensors: 29 data: 120, nonzero entries: ['g', 's', 't', 'valid']

# %%
tt.show(data)

# %%
mgr1 = tt.TravelTimeManager(data)

# %%
mgr1.showData()
# Out:
# (<Axes: >, None)

# %%
inv1 = mgr1.invert(verbose=1)
# Out:
# 16/02/24 - 20:22:54 - pyGIMLi - ERROR - <class 'pygimli.physics.traveltime.TravelTimeManager.TravelTimeManager'>.checkError(d:\Anaconda\envs\pg\lib\site-packages\pygimli\physics\traveltime\TravelTimeManager.py:98)
# DataContainer has no "err" values. Fallback to 3%
# 16/02/24 - 20:22:54 - pyGIMLi - INFO - Create gradient starting model. 500: 5000
# 16/02/24 - 20:22:54 - pyGIMLi - INFO - Created startmodel from forward operator: 414, min/max=0.000200/0.002000
# 16/02/24 - 20:22:54 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.traveltime.modelling.TravelTimeDijkstraModelling object at 0x000001B46ED46090>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x000001B46ED46130>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000001B46ED14D10>
# min/max (data): 0.0053/0.1
# min/max (error): 3%/3%
# min/max (start model): 2.0e-04/0.002
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  146.55
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    3.06 (dPhi = 96.38%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    1.51 (dPhi = 33.42%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.29 (dPhi = 7.28%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    1.19 (dPhi = 3.15%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... chi² =    0.78 (dPhi = 10.04%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.78)                   #
# ################################################################################

# %%
mgr1.showResult()
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1b475724b20>)

# %%
mgr1.showFit()

# %%
mgr1.showRayPaths()
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1b475a7a400>)

# %%
mgr2 = tt.TravelTimeManager(data)

# %%
inv2 = mgr2.invert(verbose=1, secNodes = 3, paraMaxCellSize = 5.0, zWeight = 2)
# Out:
# 16/02/24 - 20:35:47 - pyGIMLi - INFO - Found 1 regions.
# 16/02/24 - 20:35:47 - pyGIMLi - INFO - Found 1 regions.
# 16/02/24 - 20:35:47 - pyGIMLi - ERROR - <class 'pygimli.physics.traveltime.TravelTimeManager.TravelTimeManager'>.checkError(d:\Anaconda\envs\pg\lib\site-packages\pygimli\physics\traveltime\TravelTimeManager.py:98)
# DataContainer has no "err" values. Fallback to 3%
# 16/02/24 - 20:35:48 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 16/02/24 - 20:35:48 - pyGIMLi - INFO - Creating refined mesh (secnodes: 3) to solve forward task.
# 16/02/24 - 20:35:48 - pyGIMLi - INFO - Create gradient starting model. 500: 5000
# 16/02/24 - 20:35:48 - pyGIMLi - INFO - Created startmodel from forward operator: 2293, min/max=0.000200/0.002000
# 16/02/24 - 20:35:48 - pyGIMLi - INFO - Starting inversion.
# fop: <pygimli.physics.traveltime.modelling.TravelTimeDijkstraModelling object at 0x000001B48A1CA720>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x000001B48A1CA860>
# Model transformation (cumulative):
# 	 0 <pgcore._pygimli_.RTransLogLU object at 0x000001B48A1C6DC0>
# min/max (data): 0.0053/0.1
# min/max (error): 3%/3%
# min/max (start model): 2.0e-04/0.002
# --------------------------------------------------------------------------------
# inv.iter 0 ... chi² =  111.66
# --------------------------------------------------------------------------------
# inv.iter 1 ... chi² =    2.68 (dPhi = 92.69%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... chi² =    2.01 (dPhi = 13.06%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... chi² =    1.64 (dPhi = 5.42%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... chi² =    1.58 (dPhi = 0.97%) lam: 20.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.97 (< 2.0%)                 #
# ################################################################################

# %%
mgr2.showResult(cMap = 'PuOr')
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1b48afc6040>)

# %%
mgr2.showFit()

# %%
mgr2.showRayPaths()
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1b4870f69d0>)

# %%
ax, cbar = mgr2.showResult(label='Velocity [m/s]', coverage=mgr2.standardizedCoverage())
rays = mgr2.drawRayPaths(ax, lw=0.5, color='black')
